# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#from pydub import AudioSegment
#from pydub.playback import play

# %%
df = pd.read_csv("features_3_sec.csv")
labels=df['label']
num=0
one_hot_encode={}
labels_encoded=[]

for i in labels:
    if i not in one_hot_encode.keys():
        one_hot_encode[i]=num
        labels_encoded.append(num)
        num+=1
    else:
        labels_encoded.append(one_hot_encode[i])
df['labels_encoded']=labels_encoded
print(one_hot_encode)
df
# Out:
# {'blues': 0, 'classical': 1, 'country': 2, 'disco': 3, 'hiphop': 4, 'jazz': 5, 'metal': 6, 'pop': 7, 'reggae': 8, 'rock': 9}
#                filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0     blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1     blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2     blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3     blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4     blues.00000.4.wav   66149          0.335579         0.088129  0.143289
# ...                 ...     ...               ...              ...       ...
# 9985   rock.00099.5.wav   66149          0.349126         0.080515  0.050019
# 9986   rock.00099.6.wav   66149          0.372564         0.082626  0.057897
# 9987   rock.00099.7.wav   66149          0.347481         0.089019  0.052403
# 9988   rock.00099.8.wav   66149          0.387527         0.084815  0.066430
# ...

# %%
#song = AudioSegment.from_wav("samples/classical.00013.wav")

#play(song)

# %%
X = df.copy()
X.drop(['filename', 'label','length','labels_encoded'],axis=1,inplace=True)
display(X)
Y=pd.DataFrame(df['labels_encoded'])
display(Y)
# Out:
#       chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0             0.335406         0.091048  0.130405  0.003521
# 1             0.343065         0.086147  0.112699  0.001450
# 2             0.346815         0.092243  0.132003  0.004620
# 3             0.363639         0.086856  0.132565  0.002448
# 4             0.335579         0.088129  0.143289  0.001701
# ...                ...              ...       ...       ...
# 9985          0.349126         0.080515  0.050019  0.000097
# 9986          0.372564         0.082626  0.057897  0.000088
# 9987          0.347481         0.089019  0.052403  0.000701
# 9988          0.387527         0.084815  0.066430  0.000320
# 9989          0.369293         0.086759  0.050524  0.000067
#
#       spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0                1773.065032          167541.630869              1972.744388
# 1                1816.693777           90525.690866              2010.051501
# ...

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
X = clean_dataset(X)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=1000, random_state=1234)
print(x_train.shape)
# Out:
# (8990, 57)

# %%
y_train.shape
# Out:
# (8990, 1)

# %% [markdown]
# # SVM

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")

# %%
SVCmodel = SVC(kernel = 'linear')
SVCmodel.fit(x_train, y_train)
 
# print prediction results
SVCpredictions = SVCmodel.predict(x_test)
print(classification_report(y_test, SVCpredictions))

# %%
SVCparam_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['linear', 'rbf']}
 
gridSVC = GridSearchCV(SVC(), SVCparam_grid, refit = True, verbose = 3)
 
# fitting the model for grid search
gridSVC.fit(x_train, y_train)I
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits

# %%
# print best parameter after tuning
print(gridSVC.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(gridSVC.best_estimator_)

# %%
SVCgrid_predictions = gridSVC.predict(x_test)
 
# print classification report
print(classification_report(y_test, SVCgrid_predictions))

# %%
X.columns
# Out:
# Index(['chroma_stft_mean', 'chroma_stft_var', 'rms_mean', 'rms_var',
#        'spectral_centroid_mean', 'spectral_centroid_var',
#        'spectral_bandwidth_mean', 'spectral_bandwidth_var', 'rolloff_mean',
#        'rolloff_var', 'zero_crossing_rate_mean', 'zero_crossing_rate_var',
#        'harmony_mean', 'harmony_var', 'perceptr_mean', 'perceptr_var', 'tempo',
#        'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean', 'mfcc2_var', 'mfcc3_mean',
#        'mfcc3_var', 'mfcc4_mean', 'mfcc4_var', 'mfcc5_mean', 'mfcc5_var',
#        'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean', 'mfcc7_var', 'mfcc8_mean',
#        'mfcc8_var', 'mfcc9_mean', 'mfcc9_var', 'mfcc10_mean', 'mfcc10_var',
#        'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean', 'mfcc12_var', 'mfcc13_mean',
#        'mfcc13_var', 'mfcc14_mean', 'mfcc14_var', 'mfcc15_mean', 'mfcc15_var',
#        'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean', 'mfcc17_var', 'mfcc18_mean',
# ...

# %%
SVCmodel = SVC()
SVCmodel.fit(x_train, y_train)
 
# print prediction results
SVCpredictions = SVCmodel.predict(x_test)
print(classification_report(y_test, SVCpredictions))

# %%
results = pd.DataFrame()

# %% [markdown]
# #

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
X = clean_dataset(X)

# %%
from sklearn.decomposition import PCA
dummy = np.linalg.norm(X, axis=0)
stnd_dev = np.std(dummy)

reconstruction_error_list = []

for i in range(57):
    pca = PCA(n_components=i+1)
    input_transform = pca.fit_transform(X)
    input_inverse = pca.inverse_transform(input_transform)
    reconstruction_error =  ((X - input_inverse) ** 2).mean().sum()
    reconstruction_error_list.append(reconstruction_error)

# %%
reconstruction_error_list = np.array(reconstruction_error_list)
reconstruction_error_list
# Out:
# array([7.24462901e+10, 1.93071578e+09, 7.60554760e+06, 2.27096910e+06,
#        2.03212124e+05, 1.38713257e+05, 8.44311271e+04, 5.89514361e+04,
#        4.42613465e+04, 3.48862129e+04, 2.71617816e+04, 2.14146443e+04,
#        1.72849263e+04, 1.43032297e+04, 1.20944619e+04, 1.01954672e+04,
#        8.84086967e+03, 7.75943479e+03, 6.76124119e+03, 5.90456398e+03,
#        5.10863646e+03, 4.35186919e+03, 3.67401582e+03, 3.04340386e+03,
#        2.50564050e+03, 2.02298891e+03, 1.57064197e+03, 1.16187875e+03,
#        8.44585814e+02, 6.58311575e+02, 5.06649162e+02, 4.02948176e+02,
#        3.40568707e+02, 2.82667088e+02, 2.42066317e+02, 2.06323964e+02,
#        1.72841051e+02, 1.44318479e+02, 1.18102960e+02, 9.27541943e+01,
#        7.20801413e+01, 5.53486292e+01, 4.02612884e+01, 2.76428909e+01,
#        1.73009404e+01, 7.72200656e+00, 3.88248145e-03, 1.27949683e-03,
#        1.75931846e-04, 7.72127792e-05, 3.90240408e-05, 1.54583335e-05,
# ...

# %%
plt.plot(range(1,58), np.log10(reconstruction_error_list/stnd_dev), label="RMSE error")
plt.plot([1,57],[-4,-4], label = "0.01% error line")
plt.xlabel('Number of Dimensions')
plt.ylabel('RMSE(in log scale)')
plt.xlim(1,57)
plt.legend()
plt.show()

# %% [markdown]
# 10 Dimensions Suitable.

# %%
#x_train = clean_dataset(x_train)
#x_test = clean_dataset(x_test)
from sklearn.decomposition import PCA
pca = PCA(n_components=25)
X_compressed = pca.fit_transform(x_train)
Xtest_compressed = pca.transform(x_test)
X_compressed
# Out:
# array([[ 4.48881668e+06,  1.84846466e+06,  4.29760261e+04, ...,
#         -9.63223347e+00,  2.15532723e+01,  1.91782531e+01],
#        [-1.66006829e+06, -3.66972300e+04, -1.47185677e+04, ...,
#         -7.30872968e+01, -4.68736642e+01,  2.98518050e+00],
#        [-1.26167342e+06, -7.04901442e+04,  4.06698007e+04, ...,
#          5.32600854e+01, -4.03485994e+01, -4.57178754e+01],
#        ...,
#        [ 5.69923378e+05, -1.28353899e+05, -3.38426215e+04, ...,
#         -8.24873267e+00, -2.41497294e+01, -3.90406215e+00],
#        [-1.54431632e+06, -4.15055814e+04,  2.30970724e+04, ...,
#          1.30990975e+01,  7.73597473e+00, -1.52070461e+01],
#        [-5.45870774e+05, -3.64503177e+04,  1.93617047e+04, ...,
#         -1.59220891e+01,  3.35730161e+01, -3.94433578e+01]])

# %%
X_compressed.shape
# Out:
# (8990, 25)

# %%
y_train.shape
# Out:
# (8990, 1)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
X_compressed = sc.fit_transform(X_compressed)
Xtest_compressed = sc.transform(Xtest_compressed)

SVCmodel = SVC(kernel = 'linear')
SVCmodel.fit(X_compressed, y_train)
 
# print prediction results
SVCpredictions = SVCmodel.predict(Xtest_compressed)
print(classification_report(y_test, SVCpredictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.34      0.44      0.38       104
#            1       0.83      0.91      0.87       104
#            2       0.44      0.29      0.35        93
#            3       0.35      0.33      0.34        86
#            4       0.47      0.31      0.38       105
#            5       0.51      0.45      0.48       105
#            6       0.56      0.77      0.65       108
#            7       0.48      0.80      0.60        96
#            8       0.49      0.37      0.43        91
#            9       0.33      0.20      0.25       108
#
#     accuracy                           0.49      1000
#    macro avg       0.48      0.49      0.47      1000
# weighted avg       0.48      0.49      0.47      1000

# %%
SVCparam_grid = {'C': [0.1, 1],
              'gamma': [1, 0.1, 0.01, 0.001],
              'kernel': ['linear', 'rbf']}
 
gridSVC = GridSearchCV(SVC(), SVCparam_grid, refit = True, verbose = 3)
 
# fitting the model for grid search
gridSVC.fit(X_compressed, y_train)
